# %%
import numpy as np
import z3
from analysis import Polyhedron, DecoratedSeqNode, DecoratedPAssignNode, coefficients_to_z3_expression

# %%
with open('../taxinet/bright_dark/taxinet_5bins_joint_SUMMARIES.npz', 'rb') as f:
    taxinet_summaries = dict(np.load(f))

# %%
eps=0.01
wp_eps = Polyhedron(np.atleast_2d(taxinet_summaries['b_1']), np.asarray([eps]), label=f"wp((A,b),{eps})")
scen = DecoratedPAssignNode(wp_eps, wp_eps, eps, taxinet_summaries['A_1'], taxinet_summaries['b_1'], label=f"scen")
if scen.check():
    print(f"wp((A,b),{eps}) is recurrent")
else:
    print(f"eps={eps} is too low.")
# Out:
# wp((A,b),0.01) is recurrent

# %%
def find_recurrence(A, b, eps_low=0, eps_high=1, step=0.05):
    eps = eps_low
    while eps <= eps_high:
        wp_eps = Polyhedron(np.atleast_2d(b), np.asarray([eps]), label=f"wp((A,b),{eps})")
        scen = DecoratedPAssignNode(wp_eps, wp_eps, eps, A, b, label=f"scen")
        if scen.check():
            print(f"wp((A,b),{eps}) is recurrent")
        else:
            print(f"wp((A,b),{eps}) is not recurrent")
        eps += step

# %%
# This cell is how we found the invariant preconditions for applying Rule 2 to TaxiNet, as mentioned
# in section 4.3 of the submission.
print("For scenario 0 (day) we try lower and lower values of epsilon:")
find_recurrence(taxinet_summaries['A_0'], taxinet_summaries['b_0'], step=0.01)


print("For scenario 1 (night) we try lower and lower values of epsilon:")
find_recurrence(taxinet_summaries['A_1'], taxinet_summaries['b_1'], step=0.01)
# Out:
# For scenario 0 (day) we try lower and lower values of epsilon:
# wp((A,b),0) is recurrent
# wp((A,b),0.01) is recurrent
# wp((A,b),0.02) is recurrent
# wp((A,b),0.03) is recurrent
# wp((A,b),0.04) is recurrent
# wp((A,b),0.05) is recurrent
# wp((A,b),0.060000000000000005) is recurrent
# wp((A,b),0.07) is recurrent
# wp((A,b),0.08) is recurrent
# wp((A,b),0.09) is recurrent
# wp((A,b),0.09999999999999999) is recurrent
# wp((A,b),0.10999999999999999) is recurrent
# wp((A,b),0.11999999999999998) is recurrent
# wp((A,b),0.12999999999999998) is recurrent
# wp((A,b),0.13999999999999999) is recurrent
# wp((A,b),0.15) is recurrent
# wp((A,b),0.16) is recurrent
# wp((A,b),0.17) is recurrent
# wp((A,b),0.18000000000000002) is recurrent
# wp((A,b),0.19000000000000003) is recurrent
# wp((A,b),0.20000000000000004) is recurrent
# wp((A,b),0.21000000000000005) is recurrent
# wp((A,b),0.22000000000000006) is recurrent
# wp((A,b),0.23000000000000007) is recurrent
# wp((A,b),0.24000000000000007) is recurrent
# wp((A,b),0.25000000000000006) is recurrent
# wp((A,b),0.26000000000000006) is recurrent
# wp((A,b),0.2700000000000001) is recurrent
# wp((A,b),0.2800000000000001) is recurrent
# wp((A,b),0.2900000000000001) is recurrent
# wp((A,b),0.3000000000000001) is recurrent
# wp((A,b),0.3100000000000001) is recurrent
# wp((A,b),0.3200000000000001) is recurrent
# wp((A,b),0.3300000000000001) is recurrent
# wp((A,b),0.34000000000000014) is recurrent
# wp((A,b),0.35000000000000014) is recurrent
# wp((A,b),0.36000000000000015) is recurrent
# wp((A,b),0.37000000000000016) is recurrent
# wp((A,b),0.38000000000000017) is recurrent
# wp((A,b),0.3900000000000002) is recurrent
# wp((A,b),0.4000000000000002) is recurrent
# wp((A,b),0.4100000000000002) is recurrent
# wp((A,b),0.4200000000000002) is recurrent
# wp((A,b),0.4300000000000002) is recurrent
# wp((A,b),0.4400000000000002) is recurrent
# wp((A,b),0.45000000000000023) is recurrent
# wp((A,b),0.46000000000000024) is recurrent
# wp((A,b),0.47000000000000025) is recurrent
# wp((A,b),0.48000000000000026) is recurrent
# wp((A,b),0.49000000000000027) is recurrent
# wp((A,b),0.5000000000000002) is recurrent
# wp((A,b),0.5100000000000002) is recurrent
# wp((A,b),0.5200000000000002) is recurrent
# wp((A,b),0.5300000000000002) is recurrent
# wp((A,b),0.5400000000000003) is recurrent
# wp((A,b),0.5500000000000003) is recurrent
# wp((A,b),0.5600000000000003) is recurrent
# wp((A,b),0.5700000000000003) is recurrent
# wp((A,b),0.5800000000000003) is recurrent
# wp((A,b),0.5900000000000003) is recurrent
# wp((A,b),0.6000000000000003) is recurrent
# wp((A,b),0.6100000000000003) is recurrent
# wp((A,b),0.6200000000000003) is recurrent
# wp((A,b),0.6300000000000003) is recurrent
# wp((A,b),0.6400000000000003) is recurrent
# wp((A,b),0.6500000000000004) is recurrent
# wp((A,b),0.6600000000000004) is recurrent
# wp((A,b),0.6700000000000004) is recurrent
# wp((A,b),0.6800000000000004) is recurrent
# wp((A,b),0.6900000000000004) is recurrent
# wp((A,b),0.7000000000000004) is recurrent
# wp((A,b),0.7100000000000004) is recurrent
# wp((A,b),0.7200000000000004) is recurrent
# wp((A,b),0.7300000000000004) is recurrent
# wp((A,b),0.7400000000000004) is recurrent
# wp((A,b),0.7500000000000004) is recurrent
# wp((A,b),0.7600000000000005) is recurrent
# wp((A,b),0.7700000000000005) is recurrent
# wp((A,b),0.7800000000000005) is recurrent
# wp((A,b),0.7900000000000005) is recurrent
# wp((A,b),0.8000000000000005) is recurrent
# wp((A,b),0.8100000000000005) is recurrent
# wp((A,b),0.8200000000000005) is recurrent
# wp((A,b),0.8300000000000005) is recurrent
# wp((A,b),0.8400000000000005) is recurrent
# wp((A,b),0.8500000000000005) is recurrent
# wp((A,b),0.8600000000000005) is recurrent
# wp((A,b),0.8700000000000006) is recurrent
# wp((A,b),0.8800000000000006) is recurrent
# wp((A,b),0.8900000000000006) is recurrent
# wp((A,b),0.9000000000000006) is recurrent
# wp((A,b),0.9100000000000006) is recurrent
# wp((A,b),0.9200000000000006) is recurrent
# wp((A,b),0.9300000000000006) is recurrent
# wp((A,b),0.9400000000000006) is recurrent
# wp((A,b),0.9500000000000006) is recurrent
# wp((A,b),0.9600000000000006) is recurrent
# wp((A,b),0.9700000000000006) is recurrent
# wp((A,b),0.9800000000000006) is recurrent
# wp((A,b),0.9900000000000007) is recurrent
# For scenario 1 (night) we try lower and lower values of epsilon:
# wp((A,b),0) is recurrent
# wp((A,b),0.01) is recurrent
# wp((A,b),0.02) is recurrent
# wp((A,b),0.03) is recurrent
# wp((A,b),0.04) is recurrent
# wp((A,b),0.05) is recurrent
# wp((A,b),0.060000000000000005) is recurrent
# wp((A,b),0.07) is recurrent
# wp((A,b),0.08) is recurrent
# wp((A,b),0.09) is recurrent
# wp((A,b),0.09999999999999999) is recurrent
# wp((A,b),0.10999999999999999) is recurrent
# wp((A,b),0.11999999999999998) is recurrent
# wp((A,b),0.12999999999999998) is recurrent
# wp((A,b),0.13999999999999999) is recurrent
# wp((A,b),0.15) is recurrent
# wp((A,b),0.16) is recurrent
# wp((A,b),0.17) is recurrent
# wp((A,b),0.18000000000000002) is recurrent
# wp((A,b),0.19000000000000003) is recurrent
# wp((A,b),0.20000000000000004) is recurrent
# wp((A,b),0.21000000000000005) is recurrent
# wp((A,b),0.22000000000000006) is recurrent
# wp((A,b),0.23000000000000007) is recurrent
# wp((A,b),0.24000000000000007) is recurrent
# wp((A,b),0.25000000000000006) is recurrent
# wp((A,b),0.26000000000000006) is recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_2 = 0,
#  x_12 = 190000000000000/240000000000001,
#  x_5 = 0,
#  x_11 = 0,
#  x_9 = 0,
#  x_10 = 0,
#  x_0 = 0,
#  x_7 = 0,
#  x_14 = 0,
#  x_1 = 0,
#  x_6 = 50000000000001/240000000000001,
#  x_13 = 0,
#  x_8 = 0,
#  x_4 = 0]
# wp((A,b),0.2700000000000001) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_2 = 0,
#  x_12 = 90000000000000/240000000000001,
#  x_5 = 0,
#  x_11 = 0,
#  x_9 = 0,
#  x_10 = 0,
#  x_0 = 0,
#  x_7 = 0,
#  x_14 = 0,
#  x_1 = 0,
#  x_6 = 150000000000001/240000000000001,
#  x_13 = 0,
#  x_8 = 0,
#  x_4 = 0]
# wp((A,b),0.2800000000000001) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_2 = 0,
#  x_12 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_9 = 0,
#  x_10 = 0,
#  x_0 = 0,
#  x_7 = 0,
#  x_14 = 0,
#  x_1 = 0,
#  x_6 = 39/40,
#  x_13 = 0,
#  x_8 = 1/40,
#  x_4 = 0]
# wp((A,b),0.2900000000000001) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_2 = 0,
#  x_12 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_9 = 0,
#  x_10 = 0,
#  x_0 = 0,
#  x_7 = 0,
#  x_14 = 0,
#  x_1 = 0,
#  x_6 = 29/40,
#  x_13 = 0,
#  x_8 = 11/40,
#  x_4 = 0]
# wp((A,b),0.3000000000000001) is not recurrent
# wp((A,b),0.3100000000000001) is recurrent
# wp((A,b),0.3200000000000001) is recurrent
# wp((A,b),0.3300000000000001) is recurrent
# wp((A,b),0.34000000000000014) is recurrent
# wp((A,b),0.35000000000000014) is recurrent
# wp((A,b),0.36000000000000015) is recurrent
# wp((A,b),0.37000000000000016) is recurrent
# wp((A,b),0.38000000000000017) is recurrent
# wp((A,b),0.3900000000000002) is recurrent
# wp((A,b),0.4000000000000002) is recurrent
# wp((A,b),0.4100000000000002) is recurrent
# wp((A,b),0.4200000000000002) is recurrent
# wp((A,b),0.4300000000000002) is recurrent
# wp((A,b),0.4400000000000002) is recurrent
# wp((A,b),0.45000000000000023) is recurrent
# wp((A,b),0.46000000000000024) is recurrent
# wp((A,b),0.47000000000000025) is recurrent
# wp((A,b),0.48000000000000026) is recurrent
# wp((A,b),0.49000000000000027) is recurrent
# wp((A,b),0.5000000000000002) is recurrent
# wp((A,b),0.5100000000000002) is recurrent
# wp((A,b),0.5200000000000002) is recurrent
# wp((A,b),0.5300000000000002) is recurrent
# wp((A,b),0.5400000000000003) is recurrent
# wp((A,b),0.5500000000000003) is recurrent
# wp((A,b),0.5600000000000003) is recurrent
# wp((A,b),0.5700000000000003) is recurrent
# wp((A,b),0.5800000000000003) is recurrent
# wp((A,b),0.5900000000000003) is recurrent
# wp((A,b),0.6000000000000003) is recurrent
# wp((A,b),0.6100000000000003) is recurrent
# wp((A,b),0.6200000000000003) is recurrent
# wp((A,b),0.6300000000000003) is recurrent
# wp((A,b),0.6400000000000003) is recurrent
# wp((A,b),0.6500000000000004) is recurrent
# wp((A,b),0.6600000000000004) is recurrent
# wp((A,b),0.6700000000000004) is recurrent
# wp((A,b),0.6800000000000004) is recurrent
# wp((A,b),0.6900000000000004) is recurrent
# wp((A,b),0.7000000000000004) is recurrent
# wp((A,b),0.7100000000000004) is recurrent
# wp((A,b),0.7200000000000004) is recurrent
# wp((A,b),0.7300000000000004) is recurrent
# wp((A,b),0.7400000000000004) is recurrent
# wp((A,b),0.7500000000000004) is recurrent
# wp((A,b),0.7600000000000005) is recurrent
# wp((A,b),0.7700000000000005) is recurrent
# wp((A,b),0.7800000000000005) is recurrent
# wp((A,b),0.7900000000000005) is recurrent
# wp((A,b),0.8000000000000005) is recurrent
# wp((A,b),0.8100000000000005) is recurrent
# wp((A,b),0.8200000000000005) is recurrent
# wp((A,b),0.8300000000000005) is recurrent
# wp((A,b),0.8400000000000005) is recurrent
# wp((A,b),0.8500000000000005) is recurrent
# wp((A,b),0.8600000000000005) is recurrent
# wp((A,b),0.8700000000000006) is recurrent
# wp((A,b),0.8800000000000006) is recurrent
# wp((A,b),0.8900000000000006) is recurrent
# wp((A,b),0.9000000000000006) is recurrent
# wp((A,b),0.9100000000000006) is recurrent
# wp((A,b),0.9200000000000006) is recurrent
# wp((A,b),0.9300000000000006) is recurrent
# wp((A,b),0.9400000000000006) is recurrent
# wp((A,b),0.9500000000000006) is recurrent
# wp((A,b),0.9600000000000006) is recurrent
# wp((A,b),0.9700000000000006) is recurrent
# wp((A,b),0.9800000000000006) is recurrent
# wp((A,b),0.9900000000000007) is recurrent

# %%
# This cell is how we found the invariant preconditions for applying Rule 2 to F1Tenth, as mentioned
# in section 4.3 of the submission.
with open('/Users/christopherwatson/Documents/Internship/probabilistic-abstraction/NewF1Tenth/left_dnn_new/programs/summary_programs/base_05noise_summarized_multi_init_SUMMARIES.npz', 'rb') as f:
    new_f1tenth_summaries = dict(np.load(f))
print("For scenario 0 (left) we try lower and lower values of epsilon:")
find_recurrence(new_f1tenth_summaries['A_0'], new_f1tenth_summaries['b_0'], step=0.01)

print("For scenario 1 (right) we try lower and lower values of epsilon:")
find_recurrence(new_f1tenth_summaries['A_1'], new_f1tenth_summaries['b_1'], step=0.01)

print("For scenario 2 (straight) we try lower and lower values of epsilon:")
find_recurrence(new_f1tenth_summaries['A_2'], new_f1tenth_summaries['b_2'], step=0.01)
# Out:
# For scenario 0 (left) we try lower and lower values of epsilon:
# wp((A,b),0) is recurrent
# wp((A,b),0.01) is recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.02) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.03) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.04) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.05) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.060000000000000005) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.07) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.08) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.09) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.09999999999999999) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.10999999999999999) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 1,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.11999999999999998) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 7610000000000033/32130000000000000,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 24519999999999967/32130000000000000,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0.12999999999999998) is not recurrent
# wp((A,b),0.13999999999999999) is recurrent
# wp((A,b),0.15) is recurrent
# wp((A,b),0.16) is recurrent
# wp((A,b),0.17) is recurrent
# wp((A,b),0.18000000000000002) is recurrent
# wp((A,b),0.19000000000000003) is recurrent
# wp((A,b),0.20000000000000004) is recurrent
# wp((A,b),0.21000000000000005) is recurrent
# wp((A,b),0.22000000000000006) is recurrent
# wp((A,b),0.23000000000000007) is recurrent
# wp((A,b),0.24000000000000007) is recurrent
# wp((A,b),0.25000000000000006) is recurrent
# wp((A,b),0.26000000000000006) is recurrent
# wp((A,b),0.2700000000000001) is recurrent
# wp((A,b),0.2800000000000001) is recurrent
# wp((A,b),0.2900000000000001) is recurrent
# wp((A,b),0.3000000000000001) is recurrent
# wp((A,b),0.3100000000000001) is recurrent
# wp((A,b),0.3200000000000001) is recurrent
# wp((A,b),0.3300000000000001) is recurrent
# wp((A,b),0.34000000000000014) is recurrent
# wp((A,b),0.35000000000000014) is recurrent
# wp((A,b),0.36000000000000015) is recurrent
# wp((A,b),0.37000000000000016) is recurrent
# wp((A,b),0.38000000000000017) is recurrent
# wp((A,b),0.3900000000000002) is recurrent
# wp((A,b),0.4000000000000002) is recurrent
# wp((A,b),0.4100000000000002) is recurrent
# wp((A,b),0.4200000000000002) is recurrent
# wp((A,b),0.4300000000000002) is recurrent
# wp((A,b),0.4400000000000002) is recurrent
# wp((A,b),0.45000000000000023) is recurrent
# wp((A,b),0.46000000000000024) is recurrent
# wp((A,b),0.47000000000000025) is recurrent
# wp((A,b),0.48000000000000026) is recurrent
# wp((A,b),0.49000000000000027) is recurrent
# wp((A,b),0.5000000000000002) is recurrent
# wp((A,b),0.5100000000000002) is recurrent
# wp((A,b),0.5200000000000002) is recurrent
# wp((A,b),0.5300000000000002) is recurrent
# wp((A,b),0.5400000000000003) is recurrent
# wp((A,b),0.5500000000000003) is recurrent
# wp((A,b),0.5600000000000003) is recurrent
# wp((A,b),0.5700000000000003) is recurrent
# wp((A,b),0.5800000000000003) is recurrent
# wp((A,b),0.5900000000000003) is recurrent
# wp((A,b),0.6000000000000003) is recurrent
# wp((A,b),0.6100000000000003) is recurrent
# wp((A,b),0.6200000000000003) is recurrent
# wp((A,b),0.6300000000000003) is recurrent
# wp((A,b),0.6400000000000003) is recurrent
# wp((A,b),0.6500000000000004) is recurrent
# wp((A,b),0.6600000000000004) is recurrent
# wp((A,b),0.6700000000000004) is recurrent
# wp((A,b),0.6800000000000004) is recurrent
# wp((A,b),0.6900000000000004) is recurrent
# wp((A,b),0.7000000000000004) is recurrent
# wp((A,b),0.7100000000000004) is recurrent
# wp((A,b),0.7200000000000004) is recurrent
# wp((A,b),0.7300000000000004) is recurrent
# wp((A,b),0.7400000000000004) is recurrent
# wp((A,b),0.7500000000000004) is recurrent
# wp((A,b),0.7600000000000005) is recurrent
# wp((A,b),0.7700000000000005) is recurrent
# wp((A,b),0.7800000000000005) is recurrent
# wp((A,b),0.7900000000000005) is recurrent
# wp((A,b),0.8000000000000005) is recurrent
# wp((A,b),0.8100000000000005) is recurrent
# wp((A,b),0.8200000000000005) is recurrent
# wp((A,b),0.8300000000000005) is recurrent
# wp((A,b),0.8400000000000005) is recurrent
# wp((A,b),0.8500000000000005) is recurrent
# wp((A,b),0.8600000000000005) is recurrent
# wp((A,b),0.8700000000000006) is recurrent
# wp((A,b),0.8800000000000006) is recurrent
# wp((A,b),0.8900000000000006) is recurrent
# wp((A,b),0.9000000000000006) is recurrent
# wp((A,b),0.9100000000000006) is recurrent
# wp((A,b),0.9200000000000006) is recurrent
# wp((A,b),0.9300000000000006) is recurrent
# wp((A,b),0.9400000000000006) is recurrent
# wp((A,b),0.9500000000000006) is recurrent
# wp((A,b),0.9600000000000006) is recurrent
# wp((A,b),0.9700000000000006) is recurrent
# wp((A,b),0.9800000000000006) is recurrent
# wp((A,b),0.9900000000000007) is recurrent
# For scenario 1 (right) we try lower and lower values of epsilon:
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 1/4,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 0,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 3/4,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 0]
# wp((A,b),0) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 0,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 0,
#  x_7 = 67/384,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 317/384]
# wp((A,b),0.01) is not recurrent
# Passign node scen failed the Z3-based check. The model was:
# [x_3 = 0,
#  x_27 = 0,
#  x_37 = 0,
#  x_15 = 0,
#  x_20 = 0,
#  x_23 = 0,
#  x_12 = 0,
#  x_32 = 0,
#  x_9 = 0,
#  x_26 = 0,
#  x_17 = 0,
#  x_0 = 0,
#  x_19 = 0,
#  x_14 = 0,
#  x_29 = 0,
#  x_34 = 0,
#  x_39 = 0,
#  x_1 = 0,
#  x_6 = 0,
#  x_38 = 0,
#  x_31 = 0,
#  x_4 = 0,
#  x_16 = 0,
#  x_36 = 0,
#  x_2 = 0,
#  x_28 = 0,
#  x_33 = 0,
#  x_35 = 0,
#  x_5 = 0,
#  x_11 = 0,
#  x_21 = 0,
#  x_30 = 0,
#  x_10 = 0,
#  x_25 = 61/64,
#  x_7 = 0,
#  x_22 = 0,
#  x_24 = 0,
#  x_18 = 0,
#  x_13 = 0,
#  x_8 = 3/64]
# wp((A,b),0.02) is not recurrent
# wp((A,b),0.03) is recurrent
# wp((A,b),0.04) is recurrent
# wp((A,b),0.05) is recurrent
# wp((A,b),0.060000000000000005) is recurrent
# wp((A,b),0.07) is recurrent
# wp((A,b),0.08) is recurrent
# wp((A,b),0.09) is recurrent
# wp((A,b),0.09999999999999999) is recurrent
# wp((A,b),0.10999999999999999) is recurrent
# wp((A,b),0.11999999999999998) is recurrent
# wp((A,b),0.12999999999999998) is recurrent
# wp((A,b),0.13999999999999999) is recurrent
# wp((A,b),0.15) is recurrent
# wp((A,b),0.16) is recurrent
# wp((A,b),0.17) is recurrent
# wp((A,b),0.18000000000000002) is recurrent
# wp((A,b),0.19000000000000003) is recurrent
# wp((A,b),0.20000000000000004) is recurrent
# wp((A,b),0.21000000000000005) is recurrent
# wp((A,b),0.22000000000000006) is recurrent
# wp((A,b),0.23000000000000007) is recurrent
# wp((A,b),0.24000000000000007) is recurrent
# wp((A,b),0.25000000000000006) is recurrent
# wp((A,b),0.26000000000000006) is recurrent
# wp((A,b),0.2700000000000001) is recurrent
# wp((A,b),0.2800000000000001) is recurrent
# wp((A,b),0.2900000000000001) is recurrent
# wp((A,b),0.3000000000000001) is recurrent
# wp((A,b),0.3100000000000001) is recurrent
# wp((A,b),0.3200000000000001) is recurrent
# wp((A,b),0.3300000000000001) is recurrent
# wp((A,b),0.34000000000000014) is recurrent
# wp((A,b),0.35000000000000014) is recurrent
# wp((A,b),0.36000000000000015) is recurrent
# wp((A,b),0.37000000000000016) is recurrent
# wp((A,b),0.38000000000000017) is recurrent
# wp((A,b),0.3900000000000002) is recurrent
# wp((A,b),0.4000000000000002) is recurrent
# wp((A,b),0.4100000000000002) is recurrent
# wp((A,b),0.4200000000000002) is recurrent
# wp((A,b),0.4300000000000002) is recurrent
# wp((A,b),0.4400000000000002) is recurrent
# wp((A,b),0.45000000000000023) is recurrent
# wp((A,b),0.46000000000000024) is recurrent
# wp((A,b),0.47000000000000025) is recurrent
# wp((A,b),0.48000000000000026) is recurrent
# wp((A,b),0.49000000000000027) is recurrent
# wp((A,b),0.5000000000000002) is recurrent
# wp((A,b),0.5100000000000002) is recurrent
# wp((A,b),0.5200000000000002) is recurrent
# wp((A,b),0.5300000000000002) is recurrent
# wp((A,b),0.5400000000000003) is recurrent
# wp((A,b),0.5500000000000003) is recurrent
# wp((A,b),0.5600000000000003) is recurrent
# wp((A,b),0.5700000000000003) is recurrent
# wp((A,b),0.5800000000000003) is recurrent
# wp((A,b),0.5900000000000003) is recurrent
# wp((A,b),0.6000000000000003) is recurrent
# wp((A,b),0.6100000000000003) is recurrent
# wp((A,b),0.6200000000000003) is recurrent
# wp((A,b),0.6300000000000003) is recurrent
# wp((A,b),0.6400000000000003) is recurrent
# wp((A,b),0.6500000000000004) is recurrent
# wp((A,b),0.6600000000000004) is recurrent
# wp((A,b),0.6700000000000004) is recurrent
# wp((A,b),0.6800000000000004) is recurrent
# wp((A,b),0.6900000000000004) is recurrent
# wp((A,b),0.7000000000000004) is recurrent
# wp((A,b),0.7100000000000004) is recurrent
# wp((A,b),0.7200000000000004) is recurrent
# wp((A,b),0.7300000000000004) is recurrent
# wp((A,b),0.7400000000000004) is recurrent
# wp((A,b),0.7500000000000004) is recurrent
# wp((A,b),0.7600000000000005) is recurrent
# wp((A,b),0.7700000000000005) is recurrent
# wp((A,b),0.7800000000000005) is recurrent
# wp((A,b),0.7900000000000005) is recurrent
# wp((A,b),0.8000000000000005) is recurrent
# wp((A,b),0.8100000000000005) is recurrent
# wp((A,b),0.8200000000000005) is recurrent
# wp((A,b),0.8300000000000005) is recurrent
# wp((A,b),0.8400000000000005) is recurrent
# wp((A,b),0.8500000000000005) is recurrent
# wp((A,b),0.8600000000000005) is recurrent
# wp((A,b),0.8700000000000006) is recurrent
# wp((A,b),0.8800000000000006) is recurrent
# wp((A,b),0.8900000000000006) is recurrent
# wp((A,b),0.9000000000000006) is recurrent
# wp((A,b),0.9100000000000006) is recurrent
# wp((A,b),0.9200000000000006) is recurrent
# wp((A,b),0.9300000000000006) is recurrent
# wp((A,b),0.9400000000000006) is recurrent
# wp((A,b),0.9500000000000006) is recurrent
# wp((A,b),0.9600000000000006) is recurrent
# wp((A,b),0.9700000000000006) is recurrent
# wp((A,b),0.9800000000000006) is recurrent
# wp((A,b),0.9900000000000007) is recurrent
# For scenario 2 (straight) we try lower and lower values of epsilon:
# wp((A,b),0) is recurrent
# wp((A,b),0.01) is recurrent
# wp((A,b),0.02) is recurrent
# wp((A,b),0.03) is recurrent
# wp((A,b),0.04) is recurrent
# wp((A,b),0.05) is recurrent
# wp((A,b),0.060000000000000005) is recurrent
# wp((A,b),0.07) is recurrent
# wp((A,b),0.08) is recurrent
# wp((A,b),0.09) is recurrent
# wp((A,b),0.09999999999999999) is recurrent
# wp((A,b),0.10999999999999999) is recurrent
# wp((A,b),0.11999999999999998) is recurrent
# wp((A,b),0.12999999999999998) is recurrent
# wp((A,b),0.13999999999999999) is recurrent
# wp((A,b),0.15) is recurrent
# wp((A,b),0.16) is recurrent
# wp((A,b),0.17) is recurrent
# wp((A,b),0.18000000000000002) is recurrent
# wp((A,b),0.19000000000000003) is recurrent
# wp((A,b),0.20000000000000004) is recurrent
# wp((A,b),0.21000000000000005) is recurrent
# wp((A,b),0.22000000000000006) is recurrent
# wp((A,b),0.23000000000000007) is recurrent
# wp((A,b),0.24000000000000007) is recurrent
# wp((A,b),0.25000000000000006) is recurrent
# wp((A,b),0.26000000000000006) is recurrent
# wp((A,b),0.2700000000000001) is recurrent
# wp((A,b),0.2800000000000001) is recurrent
# wp((A,b),0.2900000000000001) is recurrent
# wp((A,b),0.3000000000000001) is recurrent
# wp((A,b),0.3100000000000001) is recurrent
# wp((A,b),0.3200000000000001) is recurrent
# wp((A,b),0.3300000000000001) is recurrent
# wp((A,b),0.34000000000000014) is recurrent
# wp((A,b),0.35000000000000014) is recurrent
# wp((A,b),0.36000000000000015) is recurrent
# wp((A,b),0.37000000000000016) is recurrent
# wp((A,b),0.38000000000000017) is recurrent
# wp((A,b),0.3900000000000002) is recurrent
# wp((A,b),0.4000000000000002) is recurrent
# wp((A,b),0.4100000000000002) is recurrent
# wp((A,b),0.4200000000000002) is recurrent
# wp((A,b),0.4300000000000002) is recurrent
# wp((A,b),0.4400000000000002) is recurrent
# wp((A,b),0.45000000000000023) is recurrent
# wp((A,b),0.46000000000000024) is recurrent
# wp((A,b),0.47000000000000025) is recurrent
# wp((A,b),0.48000000000000026) is recurrent
# wp((A,b),0.49000000000000027) is recurrent
# wp((A,b),0.5000000000000002) is recurrent
# wp((A,b),0.5100000000000002) is recurrent
# wp((A,b),0.5200000000000002) is recurrent
# wp((A,b),0.5300000000000002) is recurrent
# wp((A,b),0.5400000000000003) is recurrent
# wp((A,b),0.5500000000000003) is recurrent
# wp((A,b),0.5600000000000003) is recurrent
# wp((A,b),0.5700000000000003) is recurrent
# wp((A,b),0.5800000000000003) is recurrent
# wp((A,b),0.5900000000000003) is recurrent
# wp((A,b),0.6000000000000003) is recurrent
# wp((A,b),0.6100000000000003) is recurrent
# wp((A,b),0.6200000000000003) is recurrent
# wp((A,b),0.6300000000000003) is recurrent
# wp((A,b),0.6400000000000003) is recurrent
# wp((A,b),0.6500000000000004) is recurrent
# wp((A,b),0.6600000000000004) is recurrent
# wp((A,b),0.6700000000000004) is recurrent
# wp((A,b),0.6800000000000004) is recurrent
# wp((A,b),0.6900000000000004) is recurrent
# wp((A,b),0.7000000000000004) is recurrent
# wp((A,b),0.7100000000000004) is recurrent
# wp((A,b),0.7200000000000004) is recurrent
# wp((A,b),0.7300000000000004) is recurrent
# wp((A,b),0.7400000000000004) is recurrent
# wp((A,b),0.7500000000000004) is recurrent
# wp((A,b),0.7600000000000005) is recurrent
# wp((A,b),0.7700000000000005) is recurrent
# wp((A,b),0.7800000000000005) is recurrent
# wp((A,b),0.7900000000000005) is recurrent
# wp((A,b),0.8000000000000005) is recurrent
# wp((A,b),0.8100000000000005) is recurrent
# wp((A,b),0.8200000000000005) is recurrent
# wp((A,b),0.8300000000000005) is recurrent
# wp((A,b),0.8400000000000005) is recurrent
# wp((A,b),0.8500000000000005) is recurrent
# wp((A,b),0.8600000000000005) is recurrent
# wp((A,b),0.8700000000000006) is recurrent
# wp((A,b),0.8800000000000006) is recurrent
# wp((A,b),0.8900000000000006) is recurrent
# wp((A,b),0.9000000000000006) is recurrent
# wp((A,b),0.9100000000000006) is recurrent
# wp((A,b),0.9200000000000006) is recurrent
# wp((A,b),0.9300000000000006) is recurrent
# wp((A,b),0.9400000000000006) is recurrent
# wp((A,b),0.9500000000000006) is recurrent
# wp((A,b),0.9600000000000006) is recurrent
# wp((A,b),0.9700000000000006) is recurrent
# wp((A,b),0.9800000000000006) is recurrent
# wp((A,b),0.9900000000000007) is recurrent
